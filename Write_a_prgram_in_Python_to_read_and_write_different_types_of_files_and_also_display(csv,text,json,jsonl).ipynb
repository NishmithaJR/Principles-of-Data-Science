# %% [markdown]
# <a href="https://colab.research.google.com/github/NishmithaJR/Principles-of-Data-Science/blob/main/Write_a_prgram_in_Python_to_read_and_write_different_types_of_files_and_also_display(csv%2Ctext%2Cjson%2Cjsonl).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# To read and write csv file

# %%
car=pd.read_csv("/content/drive/MyDrive/Principles of Data Science/cars.csv")
car
# Out:
#     YEAR        Make                            Model                   Size  \
# 0   2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 1   2012      NISSAN                             LEAF               MID-SIZE
# 2   2013        FORD                   FOCUS ELECTRIC                COMPACT
# 3   2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 4   2013      NISSAN                             LEAF               MID-SIZE
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 7   2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 8   2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 9   2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 10  2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# ...

# %% [markdown]
# To display csv file

# %%
car.describe(include='all')
# Out:
#                YEAR   Make   Model       Size        (kW) Unnamed: 5 TYPE  \
# count     53.000000     53      53         53   53.000000         53   53
# unique          NaN      8      23          7         NaN          1    1
# top             NaN  TESLA  i-MiEV  FULL-SIZE         NaN         A1    B
# freq            NaN     23       5         21         NaN         53   53
# mean    2014.735849    NaN     NaN        NaN  190.622642        NaN  NaN
# std        1.227113    NaN     NaN        NaN  155.526429        NaN  NaN
# min     2012.000000    NaN     NaN        NaN   35.000000        NaN  NaN
# 25%     2014.000000    NaN     NaN        NaN   80.000000        NaN  NaN
# 50%     2015.000000    NaN     NaN        NaN  107.000000        NaN  NaN
# 75%     2016.000000    NaN     NaN        NaN  283.000000        NaN  NaN
# max     2016.000000    NaN     NaN        NaN  568.000000        NaN  NaN
#
#         CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# ...

# %% [markdown]
# To read and write text file

# %%
car=pd.read_table("/content/drive/MyDrive/Principles of Data Science/cars.txt")
car
# Out:
#                  mpg        cyl   disp         hp         drat          wt       qsec        vs   am   gear   carb
# 0                                               Mazda
# 1   RX4                 21         6      160     ...
# 2                                               Mazda
# 3   RX4 Wag          21            6      160     ...
# 4   Datsun 710      22.8           4      108     ...
# 5                                            Hornet 4
# 6   Drive           21.4           6      258     ...
# 7                                              Hornet
# 8   Sportabout      18.7           8    360       ...
# 9   Valiant         18.1           6    225       ...
# 10  Duster 360      14.3           8    360       ...
# 11  Merc 240D       24.4           4   146.7      ...
# 12  Merc 230        22.8           4   140.8      ...
# 13  Merc 280        19.2           6   167.6      ...
# 14  Merc 280C       17.8           6   167.6      ...
# ...

# %% [markdown]
# To display text file

# %%
car.describe(include='all')
# Out:
#                      mpg        cyl   disp         hp         drat          wt       qsec        vs   am   gear   carb
# count                                                  55
# unique                                                 51
# top                                                  Merc
# freq                                                    3

# %% [markdown]
# To read and write Json file

# %%
customer=pd.read_json("/content/drive/MyDrive/Principles of Data Science/customers.json")
customer
# Out:
#         id                          email       first      last  \
# 0        1         isidro_von@hotmail.com      Torrey      Veum
# 1        2         frederique19@gmail.com       Micah   Sanford
# 2        3              fredy54@gmail.com      Hollis     Swift
# 3        4          braxton29@hotmail.com       Perry   Leffler
# 4        5             turner59@gmail.com     Janelle   Hagenes
# ...    ...                            ...         ...       ...
# 9994  9995  delores_cruickshank@gmail.com      Robert      Batz
# 9995  9996     marley_brown32@hotmail.com       Leone   Reinger
# 9996  9997          raymond68@hotmail.com  Clementina      Bode
# 9997  9998   juston_powlowski@hotmail.com      Yvonne  Prosacco
# 9998  9999       orion.senger72@yahoo.com      Darrin  Connelly
#
#                              company                       created_at  \
# 0             Hilll, Mayert and Wolf 2014-12-25 04:06:27.981000+00:00
# ...

# %% [markdown]
# To display Json file

# %%
customer.describe(include='all')
# Out:
# <ipython-input-28-3411a95e9484>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   customer.describe(include='all')
#                  id               email   first   last      company  \
# count   9999.000000                9999    9999   9999         9999
# unique          NaN                9991    2917    474         8421
# top             NaN  susie4@hotmail.com  Selena  Block  Gleason Inc
# freq            NaN                   2      11     36            7
# first           NaN                 NaN     NaN    NaN          NaN
# last            NaN                 NaN     NaN    NaN          NaN
# mean    5000.000000                 NaN     NaN    NaN          NaN
# std     2886.607005                 NaN     NaN    NaN          NaN
# ...
