# %% [markdown]
# <a href="https://colab.research.google.com/github/NishmithaJR/Principles-of-Data-Science/blob/main/Basic_Analytics_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Import data

# %%
import pandas as pd
from pandas import DataFrame

# %% [markdown]
# 2) Creating DataFrame object from an Excel file

# %%
bank=pd.read_csv('/content/drive/MyDrive/Principles of Data Science/bank-full.csv')
bank.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome Target
# 0  unknown    5   may       261         1     -1         0  unknown     no
# 1  unknown    5   may       151         1     -1         0  unknown     no
# 2  unknown    5   may        76         1     -1         0  unknown     no
# 3  unknown    5   may        92         1     -1         0  unknown     no
# 4  unknown    5   may       198         1     -1         0  unknown     no

# %%
bankxl=pd.read_excel('/content/drive/MyDrive/Principles of Data Science/bank-full.xlsx')
bankxl.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome Target
# 0  unknown    5   may       261         1     -1         0  unknown     no
# 1  unknown    5   may       151         1     -1         0  unknown     no
# 2  unknown    5   may        76         1     -1         0  unknown     no
# 3  unknown    5   may        92         1     -1         0  unknown     no
# 4  unknown    5   may       198         1     -1         0  unknown     no

# %% [markdown]
# 3) Confirming DataFrame properties

# %%
bank.shape
# Out:
# (45211, 17)

# %%
bank.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  Target     45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# 4) Converting strings to categories

# %%
bank['age'].astype('category')
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45206    51
# 45207    71
# 45208    72
# 45209    57
# 45210    37
# Name: age, Length: 45211, dtype: category
# Categories (77, int64): [18, 19, 20, 21, ..., 92, 93, 94, 95]

# %%
bank['age']=bank['age'].astype('category')

# %%
bank['day']=bank['day'].astype('category')

# %%
bank.describe(include='category')
# Out:
#           age  education  balance    day
# count   45211      45211    45211  45211
# unique     77          4     7168     31
# top        32  secondary        0     20
# freq     2085      23202     3514   2752

# %% [markdown]
# 5) Type conversion using programming constructs

# %%
for col in['age','education']:
    bank[col]=bank[col].astype('category')
    bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  category
#  1   job        45211 non-null  category
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  category
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  category
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  Target     45211 non-null  object
# dtypes: category(4), int64(5), object(8)
# memory usage: 5.0+ MB
# ...

# %% [markdown]
# 6) Basic Descriptive status

# %% [markdown]
# Basic Visulaization

# %%
import pandas as pd

# %%
bank['balance'].mean()
# Out:
# 1362.2720576850766

# %%
balance=bank['balance']
balance.min(),balance.mean(),balance.median,balance.max()
# Out:
# (-8019,
#  1362.2720576850766,
#  <bound method NDFrame._add_numeric_operations.<locals>.median of 0        2143
#  1          29
#  2           2
#  3        1506
#  4           1
#           ...
#  45206     825
#  45207    1729
#  45208    5715
#  45209     668
#  45210    2971
#  Name: balance, Length: 45211, dtype: int64>,
#  102127)

# %%
bank.describe()
# Out:
#                 day      duration      campaign         pdays      previous
# count  45211.000000  45211.000000  45211.000000  45211.000000  45211.000000
# mean      15.806419    258.163080      2.763841     40.197828      0.580323
# std        8.322476    257.527812      3.098021    100.128746      2.303441
# min        1.000000      0.000000      1.000000     -1.000000      0.000000
# 25%        8.000000    103.000000      1.000000     -1.000000      0.000000
# 50%       16.000000    180.000000      2.000000     -1.000000      0.000000
# 75%       21.000000    319.000000      3.000000     -1.000000      0.000000
# max       31.000000   4918.000000     63.000000    871.000000    275.000000

# %% [markdown]
# 7) Histograms in seaborn

# %% [markdown]
# Loading the library

# %%
import seaborn as sns

# %% [markdown]
# 8) Creating a histogram

# %%
sns.histplot(x=bank['education'])
# Out:
# <Axes: xlabel='education', ylabel='Count'>

# %%
sns.histplot(x=bank['education'],bins=10,kde=True);

# %%
sns.histplot(x=bank['education'],bins=10,kde=False, stat="probability",color='green');

# %% [markdown]
# 9) Filtering data

# %% [markdown]
# Preliminaries

# %%
import pandas as pd
bank=pd.read_csv('/content/drive/MyDrive/Principles of Data Science/bank-full.csv')

# %% [markdown]
# 10) Boolean vectors

# %%
bank['job']=='management'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45206    False
# 45207    False
# 45208    False
# 45209    False
# 45210    False
# Name: job, Length: 45211, dtype: bool

# %%
bank[bank['job']=="management"]
# Out:
#        age         job  marital  education default  balance housing loan  \
# 0       58  management  married   tertiary      no     2143     yes   no
# 5       35  management  married   tertiary      no      231     yes   no
# 6       28  management   single   tertiary      no      447     yes  yes
# 21      56  management  married   tertiary      no      779     yes   no
# 26      39  management   single   tertiary      no      255     yes   no
# ...    ...         ...      ...        ...     ...      ...     ...  ...
# 45192   29  management   single   tertiary      no      765      no   no
# 45194   59  management  married   tertiary      no      138     yes  yes
# 45197   36  management   single  secondary      no     1511     yes   no
# 45198   37  management  married   tertiary      no     1428      no   no
# 45201   53  management  married   tertiary      no      583      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
marriedemployess=bank[bank['marital']=='married']
type(marriedemployess)
marriedemployess
# Out:
#        age           job  marital  education default  balance housing loan  \
# 0       58    management  married   tertiary      no     2143     yes   no
# 2       33  entrepreneur  married  secondary      no        2     yes  yes
# 3       47   blue-collar  married    unknown      no     1506     yes   no
# 5       35    management  married   tertiary      no      231     yes   no
# 8       58       retired  married    primary      no      121     yes   no
# ...    ...           ...      ...        ...     ...      ...     ...  ...
# 45204   73       retired  married  secondary      no     2850      no   no
# 45206   51    technician  married   tertiary      no      825      no   no
# 45208   72       retired  married  secondary      no     5715      no   no
# 45209   57   blue-collar  married  secondary      no      668      no   no
# 45210   37  entrepreneur  married  secondary      no     2971      no   no
#
# ...

# %%
marriedemployess['balance'].mean()
# Out:
# 1425.9255897699713

# %%
round(marriedemployess['balance'].mean(),2)
# Out:
# 1425.93

# %% [markdown]
# Complex filtering criteria

# %%
(bank['age']=='58')&(bank['campaign']==1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45206    False
# 45207    False
# 45208    False
# 45209    False
# 45210    False
# Length: 45211, dtype: bool

# %%
bank[(bank['age']=='58')&(bank['campaign']==1)].shape
# Out:
# (0, 17)

# %% [markdown]
# Filtering by a list

# %%
bank[bank['duration']>=4]
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
mgmt=[4,5,6]
bank[bank['duration'].isin(mgmt)]
# Out:
#        age          job   marital  education default  balance housing loan  \
# 284     30  blue-collar    single  secondary      no        0     yes   no
# 1530    31     services   married    primary      no     -732     yes   no
# 2987    37       admin.  divorced  secondary      no     -113     yes   no
# 3983    34   management  divorced   tertiary      no      488     yes   no
# 4304    28       admin.    single  secondary      no      350     yes  yes
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 44983   35  blue-collar  divorced    unknown      no      172      no   no
# 44988   27   unemployed    single    primary      no       93      no   no
# 45001   25   management    single   tertiary      no     1650     yes   no
# 45027   39     services    single  secondary      no      471      no   no
# 45062   58      retired   married    primary      no      742      no   no
#
# ...
